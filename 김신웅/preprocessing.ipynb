# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\kshw1\Desktop\Study\중급프로그래밍\project_git\김신웅\intergrate\총전월세.csv')
df.head()
# Out:
# C:\Users\kshw1\AppData\Local\Temp\ipykernel_1296\490862599.py:1: DtypeWarning: Columns (11,18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'C:\Users\kshw1\Desktop\Study\중급프로그래밍\project_git\김신웅\intergrate\총전월세.csv')
#    NO            시군구   번지   본번  부번    단지명 전월세구분  전용면적(㎡)    계약년월  계약일  ...  \
# 0   1  서울특별시 성동구 옥수동  250  250   0   옥수삼성    전세    84.82  201101    3  ...
# 1   2  서울특별시 성동구 옥수동  100  100   0  옥수하이츠    전세    84.86  201101    3  ...
# 2   3  서울특별시 성동구 옥수동    4    4   0     현대    전세    71.05  201101    3  ...
# 3   4  서울특별시 성동구 옥수동  250  250   0   옥수삼성    전세    84.82  201101    4  ...
# 4   5  서울특별시 성동구 옥수동    4    4   0     현대    월세    71.05  201101    4  ...
#
#   월세금(만원)     층  건축년도         도로명 계약기간 계약구분 갱신요구권 사용 종전계약 보증금(만원) 종전계약 월세(만원)  \
# 0       0  14.0  1999    독서당로 218    -    -        -          NaN         NaN
# 1       0   2.0  1998     한림말길 48    -    -        -          NaN         NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2228121 entries, 0 to 2228120
# Data columns (total 21 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   NO            int64
#  1   시군구           object
#  2   번지            object
#  3   본번            int64
#  4   부번            int64
#  5   단지명           object
#  6   전월세구분         object
#  7   전용면적(㎡)       float64
#  8   계약년월          int64
#  9   계약일           int64
#  10  보증금(만원)       object
#  11  월세금(만원)       object
#  12  층             float64
#  13  건축년도          int64
#  14  도로명           object
#  15  계약기간          object
#  16  계약구분          object
#  17  갱신요구권 사용      object
#  18  종전계약 보증금(만원)  object
#  19  종전계약 월세(만원)   object
#  20  주택유형          object
# dtypes: float64(2), int64(6), object(13)
# memory usage: 357.0+ MB

# %%
df.tail()
# Out:
#              NO            시군구   번지   본번  부번                   단지명 전월세구분  \
# 2228116  110128  서울특별시 마포구 염리동  532  532   0             마포프레스티지자이    전세
# 2228117  110129  서울특별시 마포구 염리동  532  532   0             마포프레스티지자이    전세
# 2228118  110130  서울특별시 마포구 염리동  532  532   0             마포프레스티지자이    월세
# 2228119  110131  서울특별시 마포구 염리동  532  532   0             마포프레스티지자이    전세
# 2228120  110132  서울특별시 마포구 염리동  533  533   0  마포자이더센트리지(102동~112동)    전세
#
#          전용면적(㎡)    계약년월  계약일  ... 월세금(만원)     층  건축년도        도로명  \
# 2228116    59.88  202303   18  ...       0   4.0  2021  대흥로24길 24
# 2228117    59.88  202303   18  ...       0  11.0  2021  대흥로24길 24
# 2228118    84.94  202303   18  ...     140   1.0  2021  대흥로24길 24
# 2228119    84.81  202303   18  ...       0   9.0  2021  대흥로24길 24
# 2228120    84.99  202303   21  ...       0  12.0  2022     숭문길 98
#
#                   계약기간 계약구분 갱신요구권 사용 종전계약 보증금(만원) 종전계약 월세(만원) 주택유형
# ...

# %%
df.isnull().sum()
# Out:
# NO                    0
# 시군구                   0
# 번지                    0
# 본번                    0
# 부번                    0
# 단지명                   0
# 전월세구분                 0
# 전용면적(㎡)               0
# 계약년월                  0
# 계약일                   0
# 보증금(만원)               0
# 월세금(만원)               0
# 층                     1
# 건축년도                  0
# 도로명                   0
# 계약기간                  0
# 계약구분                  0
# 갱신요구권 사용              0
# 종전계약 보증금(만원)    2080181
# 종전계약 월세(만원)     2080181
# 주택유형                  0
# dtype: int64
