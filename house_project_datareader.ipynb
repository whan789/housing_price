# %%
import warnings
import pandas as pd
import numpy as np

# %%
sigungu_df = pd.read_csv('./sigungu_code.csv', encoding='cp949')
sigungu_df.head()
# Out:
#    시군구코드  법정동코드  행정동코드    시도명 시군구명 법정동명   행정동명     적용시작일     적용만료일
# 0  11680  10600    675  서울특별시  강남구  대치동   개포3동  20221223  99991231
# 1  11680  10300    675  서울특별시  강남구  개포동   개포3동  20221223  99991231
# 2  11680  11400    675  서울특별시  강남구  일원동   개포3동  20221223  99991231
# 3  11740  10300    525  서울특별시  강동구  상일동  상일제1동  20210701  99991231
# 4  11740  10300    526  서울특별시  강동구  상일동  상일제2동  20210701  99991231

# %%
sigungu_df = sigungu_df[['시군구코드','시군구명']]
sigungu_df = sigungu_df.drop_duplicates()
sigungu_df = sigungu_df.reset_index(drop=True)
sigungu_df = sigungu_df.dropna()
sigungu_df
# Out:
#     시군구코드  시군구명
# 0   11680   강남구
# 1   11740   강동구
# 2   11290   성북구
# 3   11530   구로구
# 4   11305   강북구
# 5   11410  서대문구
# 6   11500   강서구
# 7   11440   마포구
# 8   11710   송파구
# 9   11230  동대문구
# 10  11140    중구
# 11  11110   종로구
# 12  11350   노원구
# 13  11620   관악구
# 14  11590   동작구
# 15  11560  영등포구
# 16  11200   성동구
# 17  11170   용산구
# 18  11380   은평구
# 19  11260   중랑구
# 20  11215   광진구
# 21  11545   금천구
# 22  11320   도봉구
# 23  11650   서초구
# 24  11470   양천구

# %%
sigungu_list = list(sigungu_df['시군구코드'])
sigungu_list
# Out:
# [11680,
#  11740,
#  11290,
#  11530,
#  11305,
#  11410,
#  11500,
#  11440,
#  11710,
#  11230,
#  11140,
#  11110,
#  11350,
#  11620,
#  11590,
#  11560,
#  11200,
#  11170,
#  11380,
#  11260,
#  11215,
#  11545,
#  11320,
#  11650,
#  11470]

# %%
import PublicDataReader as pdr

# %%
# 오픈 API 서비스키 입력
service_key = "JEzO8dJIlLTP5vOiYpxqEbr1ZWHkAz1cvnJ6EqBp528pB%2FBEbovCkz6jDb8NALCkXIoW7FX0J1%2FlwMOkGkxQlQ%3D%3D"

# %%
from PublicDataReader import TransactionPrice as tp
api = tp(service_key)

# %%
import pandas as pd
warnings.filterwarnings(action='ignore')

def get_data_for_sigungu(sigungu_code):
    return api.get_data(
        property_type="아파트",
        trade_type="매매",
        sigungu_code=sigungu_code,
        start_year_month="202201",
        end_year_month="202212"
    )

combined_df = pd.concat(map(get_data_for_sigungu, sigungu_list))
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[113], line 13
#       4 def get_data_for_sigungu(sigungu_code):
#       5     return api.get_data(
#       6         property_type="아파트",
#       7         trade_type="매매",
#    (...)
#      10         end_year_month="202212"
#      11     )
# ---> 13 combined_df = pd.concat(map(get_data_for_sigungu, sigungu_list))
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/reshape/concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
#     391     copy=copy,
#     392     sort=sort,
#     393 )
#     395 return op.get_result()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/reshape/concat.py:445, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     442 self.verify_integrity = verify_integrity
#     443 self.copy = copy
# --> 445 objs, keys = self._clean_keys_and_objs(objs, keys)
#     447 # figure out what our result ndim is going to be
#     448 ndims = self._get_ndims(objs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/reshape/concat.py:504, in _Concatenator._clean_keys_and_objs(self, objs, keys)
#     502     objs_list = [objs[k] for k in keys]
#     503 else:
# --> 504     objs_list = list(objs)
#     506 if len(objs_list) == 0:
#     507     raise ValueError("No objects to concatenate")
#
# Cell In[113], line 5, in get_data_for_sigungu(sigungu_code)
#       4 def get_data_for_sigungu(sigungu_code):
# ----> 5     return api.get_data(
#       6         property_type="아파트",
#       7         trade_type="매매",
#       8         sigungu_code=sigungu_code,
#       9         start_year_month="202201",
#      10         end_year_month="202212"
#      11     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/PublicDataReader/PublicDataPortal/molit.py:177, in TransactionPrice.get_data(self, property_type, trade_type, sigungu_code, year_month, start_year_month, end_year_month, verbose, **kwargs)
#     175 if res_json['response']['header']['resultCode'] != '00':
#     176     error_message = res_json['response']['header']['resultMsg']
# --> 177     raise Exception(error_message)
#     178 items = res_json['response']['body']['items']
#     179 if not items:
#
# Exception: SERVICE KEY IS NOT REGISTERED ERROR.
